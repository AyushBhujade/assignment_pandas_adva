# %%
import pandas as pd

# %% [markdown]
# quation 1:
# there are many types function in pandas
# function are
# 1)head()
# 2)tail()
# 3)groupby()
# 4)reindex()
# 5)plot()
# 6)apply()
# 7)applymap()
# 8)sort_value

# %%
df2=pd.read_csv("services.csv")

# %%
df2.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df2.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df2.reindex(["a",'b','c','d','e','f','g','h'])
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# a NaN          NaN         NaN               NaN            NaN
# b NaN          NaN         NaN               NaN            NaN
# c NaN          NaN         NaN               NaN            NaN
# d NaN          NaN         NaN               NaN            NaN
# e NaN          NaN         NaN               NaN            NaN
# f NaN          NaN         NaN               NaN            NaN
# g NaN          NaN         NaN               NaN            NaN
# h NaN          NaN         NaN               NaN            NaN
#
#   application_process audience description eligibility email  ...  \
# a                 NaN      NaN         NaN         NaN   NaN  ...
# b                 NaN      NaN         NaN         NaN   NaN  ...
# c                 NaN      NaN         NaN         NaN   NaN  ...
# d                 NaN      NaN         NaN         NaN   NaN  ...
# ...

# %%
df3=df2.groupby("location_id")

# %%
df2["new_column"]=df2["location_id"].apply(lambda x:x**2)

# %%
df2.sort_values("location_id",ascending=False)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 22  23           22         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 20  21           21         NaN                       NaN
# 19  20           20         NaN                       NaN
# 18  19           19         NaN                       NaN
# 17  18           18         NaN                       NaN
# 16  17           17         NaN                       NaN
# 15  16           16         NaN                       NaN
# 14  15           15         NaN                       NaN
# 13  14           14         NaN                       NaN
# 12  13           13         NaN                       NaN
# 11  12           12         NaN                       NaN
# 10  11           11         NaN                       NaN
# 9   10           10         NaN                       NaN
# 8    9            9         NaN                       NaN
# ...

# %% [markdown]
# quation 2:

# %%
df3=pd.DataFrame({"a":[1,2,3,4,5],"b":[4,5,7,8,9],"c":[9,6,7,2,5]})
df3.reindex([1,2,3,4])
# Out:
#    a  b  c
# 1  2  5  6
# 2  3  7  7
# 3  4  8  2
# 4  5  9  5

# %% [markdown]
# quation 3:

# %%
df=pd.DataFrame({"values":[10, 20, 30, 40, 50]})

# %%
df["values"][0:3].sum()
# Out:
# 60

# %% [markdown]
# quation 4:

# %%
df=pd.DataFrame({"text":["PW Skills is your one-stop-shop for upscaling. Get maximum value for timeand resources you invest, with job-ready courses & high-technology,available at the lowest cost."]})
df["word_count"]=df["text"].apply(len)

# %%
df
# Out:
#                                                 text  word_count
# 0  PW Skills is your one-stop-shop for upscaling....         169

# %% [markdown]
# quation 5:

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# quation 6

# %% [markdown]
# pd.read_excel() funtion is used for read excel file

# %% [markdown]
# quation 7:

# %%
df3=pd.DataFrame({'Email':["john.doe@example.com"]})
df3["user_name"]=df3["Email"].str.split('@').str.get(0)

# %%
df3
# Out:
#                   Email user_name
# 0  john.doe@example.com  john.doe

# %% [markdown]
# quation 8:

# %%
 df=pd.DataFrame({'a':[3,8,6,2,9],'b':[5,2,9,3,1],'c':[1,7,4,5,2]})

# %%
def data(df):
    filter_data=(df['a']>5)&(df['b']<10)
    return filter_data

# %%
row=df[data(df)]

# %%
print(row)
# Out:
#    a  b  c  new_file
# 1  8  2  7      True
# 2  6  9  4      True
# 4  9  1  2      True

# %% [markdown]
# quation 9:

# %%
df=pd.DataFrame({"values":[4,1,2,8,7,9,6,6]})

# %%
def descibe(df):
    print(df["values"].mean())
    print(df["values"].median())
    print(df["values"].std())
    return

# %%
descibe(df)
# Out:
# 5.375
# 6.0
# 2.8252686345094435

# %% [markdown]
# quation 10:

# %%
dict={"sale":[10,12,14,18,19,20,25],"date":["2023-01-01","2023-01-02","2023-01-03","2023-01-04","2023-01-05","2023-01-06",'2023-01-07']}

# %%
df2=pd.DataFrame(dict)
df2
# Out:
#    sale        date
# 0    10  2023-01-01
# 1    12  2023-01-02
# 2    14  2023-01-03
# 3    18  2023-01-04
# 4    19  2023-01-05
# 5    20  2023-01-06
# 6    25  2023-01-07

# %%
df2["movies_avrage"]=df["sale"].rolling(window=7).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sale'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# quation 12:

# %%
df=pd.date_range(start="2023-01-01",end="2023-01-31")

# %%
df
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# quation 13:
